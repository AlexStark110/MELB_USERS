# %%
pip install PyGithub
# Out:
# Collecting PyGithub
#   Downloading PyGithub-2.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting pynacl>=1.4.0 (from PyGithub)
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: requests>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from PyGithub) (2.32.3)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub) (2.9.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from PyGithub) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from PyGithub) (2.2.3)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.10/dist-packages (from PyGithub) (1.2.14)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub) (43.0.3)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from pynacl>=1.4.0->PyGithub) (1.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.14.0->PyGithub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.14.0->PyGithub) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.14.0->PyGithub) (2024.8.30)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated->PyGithub) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub) (2.22)
# Downloading PyGithub-2.4.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.6/362.6 kB 14.1 MB/s eta 0:00:00
# Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 31.7 MB/s eta 0:00:00
# Installing collected packages: pynacl, PyGithub
# Successfully installed PyGithub-2.4.0 pynacl-1.5.0

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)

# %% [markdown]
# Scraper script

# %%
import requests
import csv
import time
from github import Github

# GitHub API token
GITHUB_TOKEN = 'github token' #hidden for privacy concerns
HEADERS = {"Authorization": f"token {GITHUB_TOKEN}"}

# Helper function to clean up company names
def clean_company_name(company):
    if company:
        company = company.strip().lstrip('@').upper()
    return company

# Function to fetch users from the GitHub API
def fetch_users(city="Melbourne", min_followers=100):
    users = []
    page = 1

    while True:
        url = f"https://api.github.com/search/users?q=location:{city}+followers:>{min_followers}&page={page}&per_page=100"
        response = requests.get(url, headers=HEADERS)
        data = response.json()

        # Break if no more results
        if 'items' not in data or not data['items']:
            break

        for user in data['items']:
            # Get full user info
            user_url = user['url']
            user_response = requests.get(user_url, headers=HEADERS)
            user_data = user_response.json()

            # Extract required fields
            users.append({
                'login': user_data['login'],
                'name': user_data['name'],
                'company': clean_company_name(user_data['company']),
                'location': user_data['location'],
                'email': user_data['email'],
                'hireable': user_data['hireable'],
                'bio': user_data['bio'],
                'public_repos': user_data['public_repos'],
                'followers': user_data['followers'],
                'following': user_data['following'],
                'created_at': user_data['created_at'],
            })
        page += 1
        time.sleep(1)  # Avoid hitting API rate limits

    return users

# Function to fetch repositories for a user
def fetch_repositories(user_login):
    repositories = []
    page = 1

    while True:
        url = f"https://api.github.com/users/{user_login}/repos?per_page=100&page={page}"
        response = requests.get(url, headers=HEADERS)
        repo_data = response.json()

        # Break if no more repositories
        if not repo_data:
            break

        for repo in repo_data:
            repositories.append({
                'login': user_login,
                'full_name': repo['full_name'],
                'created_at': repo['created_at'],
                'stargazers_count': repo['stargazers_count'],
                'watchers_count': repo['watchers_count'],
                'language': repo['language'],
                'has_projects': repo['has_projects'],
                'has_wiki': repo['has_wiki'],
                'license_name': repo['license']['key'] if repo['license'] else None,
            })

        # If fewer than 100 repositories are returned, it means we're on the last page
        if len(repo_data) < 100:
            break

        page += 1  # Move to the next page
        time.sleep(1)  # Avoid hitting API rate limits

    return repositories

# Save users to CSV
def save_users_to_csv(users, filename="users.csv"):
    with open(filename, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=users[0].keys())
        writer.writeheader()
        writer.writerows(users)

# Save repositories to CSV
def save_repositories_to_csv(repositories, filename="repositories.csv"):
    with open(filename, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=repositories[0].keys())
        writer.writeheader()
        writer.writerows(repositories)

# Create README.md
def create_readme():
    with open('README.md', 'w') as file:
        file.write('''
* This project scrapes GitHub users in Melbourne with over 100 followers and their repositories.
* The most interesting fact found was the diversity of programming languages used.
* Developers should consider contributing to open-source projects to increase their visibility.

# GitHub Users and Repositories in Melbourne

This project uses the GitHub API to scrape users in Melbourne with over 100 followers and their repositories. The data is saved in `users.csv` and `repositories.csv`.

## Files

- `users.csv`: Contains information about each user.
- `repositories.csv`: Contains information about each user's repositories.

## How to Run

1. Set up a GitHub personal access token.
2. Run the script to fetch data and generate CSV files.
3. Upload the files to a GitHub repository.
''')

# Create a new GitHub repository and upload files
def create_github_repo():
    g = Github(GITHUB_TOKEN)
    user = g.get_user()
    repo = user.create_repo("MELB_USERS")

    # Upload files to the repository
    with open('users.csv', 'r') as file:
        content = file.read()
        repo.create_file('users.csv', 'Initial commit', content)

    with open('repositories.csv', 'r') as file:
        content = file.read()
        repo.create_file('repositories.csv', 'Initial commit', content)

    with open('README.md', 'r') as file:
        content = file.read()
        repo.create_file('README.md', 'Initial commit', content)

def main():
    print("Fetching users...")
    users = fetch_users()
    save_users_to_csv(users)
    print(f"Saved {len(users)} users to users.csv")

    print("Fetching repositories...")
    all_repositories = []
    for user in users:
        user_repos = fetch_repositories(user["login"])
        all_repositories.extend(user_repos)
        print(f"Fetched {len(user_repos)} repositories for user {user['login']}")

    save_repositories_to_csv(all_repositories)
    print(f"Saved {len(all_repositories)} repositories to repositories.csv")

    create_readme()
    create_github_repo()
    print("Created GitHub repository MELB_USERS and uploaded files.")

if __name__ == "__main__":
    main()
# Out:
# Fetching users...
# Saved 331 users to users.csv
# Fetching repositories...
# Fetched 27 repositories for user mosh-hamedani
# Fetched 35 repositories for user TheCherno
# Fetched 372 repositories for user haileys
# Fetched 562 repositories for user rstacruz
# Fetched 60 repositories for user jesseduffield
# Fetched 442 repositories for user basarat
# Fetched 240 repositories for user markdalgleish
# Fetched 78 repositories for user JakeLin
# Fetched 54 repositories for user binarythistle
# Fetched 229 repositories for user radar
# Fetched 124 repositories for user mishmanners
# Fetched 50 repositories for user timacdonald
# Fetched 2 repositories for user TuPayChain
# Fetched 156 repositories for user md-5
# Fetched 171 repositories for user thomasdavis
# Fetched 249 repositories for user geelen
# Fetched 46 repositories for user MugunthKumar
# Fetched 122 repositories for user tseemann
# Fetched 316 repositories for user loftwah
# Fetched 14 repositories for user rogerclarkmelbourne
# Fetched 185 repositories for user jxom
# Fetched 57 repositories for user rrwick
# Fetched 303 repositories for user abruzzi
# Fetched 163 repositories for user kitsonk
# Fetched 16 repositories for user mattgallagher
# Fetched 171 repositories for user sidorares
# Fetched 125 repositories for user benschwarz
# Fetched 305 repositories for user philnash
# Fetched 51 repositories for user Viralmaniar
# Fetched 89 repositories for user iancoleman
# Fetched 108 repositories for user brendanzab
# Fetched 18 repositories for user dpgeorge
# Fetched 369 repositories for user tmeasday
# Fetched 57 repositories for user Expensify
# Fetched 17 repositories for user AliasIO
# Fetched 179 repositories for user jcouyang
# Fetched 68 repositories for user kivikakk
# Fetched 68 repositories for user nnethercote
# Fetched 101 repositories for user ryanseddon
# Fetched 104 repositories for user jaydenseric
# Fetched 30 repositories for user initstring
# Fetched 124 repositories for user Anon-Exploiter
# Fetched 33 repositories for user bardiharborow
# Fetched 213 repositories for user xaviershay
# Fetched 0 repositories for user elliotcondon
# Fetched 99 repositories for user dicook
# Fetched 37 repositories for user Karolyna84
# Fetched 19 repositories for user priseborough
# Fetched 118 repositories for user wahyd4
# Fetched 156 repositories for user drewnoakes
# Fetched 62 repositories for user wireghoul
# Fetched 221 repositories for user pat
# Fetched 31 repositories for user abolkog
# Fetched 186 repositories for user fraserxu
# Fetched 273 repositories for user mokagio
# Fetched 7 repositories for user trevorstephens
# Fetched 20 repositories for user amanda08
# Fetched 105 repositories for user toolmantim
# Fetched 168 repositories for user daurnimator
# Fetched 224 repositories for user mitchmindtree
# Fetched 120 repositories for user hamishwillee
# Fetched 44 repositories for user kolber
# Fetched 72 repositories for user joho
# Fetched 163 repositories for user hugomd
# Fetched 55 repositories for user UnexpectedMaker
# Fetched 57 repositories for user merill
# Fetched 140 repositories for user jagregory
# Fetched 127 repositories for user moroshko
# Fetched 51 repositories for user davkean
# Fetched 303 repositories for user jni
# Fetched 219 repositories for user chendo
# Fetched 183 repositories for user Benjamin-Dobell
# Fetched 31 repositories for user justinsteven
# Fetched 25 repositories for user nickgammon
# Fetched 119 repositories for user evgenyneu
# Fetched 138 repositories for user azz
# Fetched 48 repositories for user taitems
# Fetched 16 repositories for user alexhude
# Fetched 8 repositories for user waferbaby
# Fetched 123 repositories for user Sutto
# Fetched 25 repositories for user chrisleekr
# Fetched 181 repositories for user aidansteele
# Fetched 338 repositories for user sj26
# Fetched 7 repositories for user justinfrench
# Fetched 69 repositories for user vektah
# Fetched 32 repositories for user aaronparker
# Fetched 58 repositories for user aershov24
# Fetched 449 repositories for user wolfeidau
# Fetched 254 repositories for user eugeneware
# Fetched 356 repositories for user deoxxa
# Fetched 217 repositories for user Rosuav
# Fetched 105 repositories for user tabs-not-spaces
# Fetched 114 repositories for user ihadeed
# Fetched 3 repositories for user edhinrichsen
# Fetched 87 repositories for user RManLuo
# Fetched 9 repositories for user AndiiCodes
# Fetched 73 repositories for user rfk
# Fetched 39 repositories for user srikat
# Fetched 92 repositories for user devgeeks
# Fetched 161 repositories for user joshwnj
# Fetched 27 repositories for user andyyhope
# Fetched 62 repositories for user KaelWD
# Fetched 119 repositories for user psifertex
# Fetched 36 repositories for user alanjrogers
# Fetched 81 repositories for user pact-foundation
# Fetched 146 repositories for user pjf
# Fetched 69 repositories for user brainstorm
# Fetched 140 repositories for user dekz
# Fetched 8 repositories for user mohammadKarimi
# Fetched 97 repositories for user lox
# Fetched 45 repositories for user abcminiuser
# Fetched 72 repositories for user sbarski
# Fetched 43 repositories for user timusus
# Fetched 29 repositories for user jonoxer
# Fetched 84 repositories for user ntwb
# Fetched 100 repositories for user Alhadis
# Fetched 56 repositories for user pento
# Fetched 11 repositories for user benhoskings
# Fetched 53 repositories for user MelbourneDeveloper
# Fetched 142 repositories for user japgolly
# Fetched 60 repositories for user hawkowl
# Fetched 12 repositories for user a1studmuffin
# Fetched 53 repositories for user camjackson
# Fetched 15 repositories for user alexbrainman
# Fetched 17 repositories for user LucasGarcez
# Fetched 66 repositories for user snyff
# Fetched 157 repositories for user eliocamp
# Fetched 10 repositories for user ninxsoft
# Fetched 9 repositories for user AlexDBlack
# Fetched 6 repositories for user marcusvolz
# Fetched 50 repositories for user nelix
# Fetched 93 repositories for user JoshuaBatty
# Fetched 72 repositories for user BeauNouvelle
# Fetched 29 repositories for user skorks
# Fetched 166 repositories for user RoyalIcing
# Fetched 4 repositories for user ComponentFactory
# Fetched 22 repositories for user bentrengrove
# Fetched 431 repositories for user karkranikhil
# Fetched 96 repositories for user SebastianElvis
# Fetched 22 repositories for user notahat
# Fetched 15 repositories for user sampage
# Fetched 138 repositories for user sporto
# Fetched 94 repositories for user abcoathup
# Fetched 163 repositories for user navidcy
# Fetched 37 repositories for user lachlanhardy
# Fetched 162 repositories for user mefellows
# Fetched 43 repositories for user djmdjm
# Fetched 137 repositories for user yob
# Fetched 29 repositories for user grahamegrieve
# Fetched 57 repositories for user dhotson
# Fetched 28 repositories for user arttnba3
# Fetched 39 repositories for user Mair
# Fetched 113 repositories for user xiaodaigh
# Fetched 40 repositories for user ychescale9
# Fetched 458 repositories for user dipjyotimetia
# Fetched 29 repositories for user DWilliames
# Fetched 103 repositories for user 0neSe7en
# Fetched 81 repositories for user ACloudGuru
# Fetched 17 repositories for user mikefarah
# Fetched 27 repositories for user mihar-22
# Fetched 107 repositories for user davidwengier
# Fetched 235 repositories for user stevage
# Fetched 25 repositories for user crafterm
# Fetched 71 repositories for user tomdalling
# Fetched 35 repositories for user adammurdoch
# Fetched 358 repositories for user maks
# Fetched 83 repositories for user jessedc
# Fetched 99 repositories for user 99designs
# Fetched 60 repositories for user jarshwah
# Fetched 79 repositories for user varund7726
# Fetched 11 repositories for user domesticcatsoftware
# Fetched 105 repositories for user mblode
# Fetched 65 repositories for user KelvinJin
# Fetched 12 repositories for user vinhphunguyen
# Fetched 50 repositories for user jeromyanglim
# Fetched 38 repositories for user chris-horner
# Fetched 0 repositories for user SEEK-Jobs
# Fetched 66 repositories for user magnetikonline
# Fetched 17 repositories for user mattnotmax
# Fetched 0 repositories for user feit-comp30023-2024
# Fetched 180 repositories for user sammcj
# Fetched 35 repositories for user nathanielw
# Fetched 162 repositories for user neekey
# Fetched 89 repositories for user jimjam-slam
# Fetched 12 repositories for user mukul500
# Fetched 69 repositories for user ash47
# Fetched 4 repositories for user rmit-computing-technologies
# Fetched 74 repositories for user MattCowgill
# Fetched 22 repositories for user benbarsdell
# Fetched 8 repositories for user bcgit
# Fetched 216 repositories for user willvelida
# Fetched 105 repositories for user ericjiang97
# Fetched 47 repositories for user kmkurn
# Fetched 62 repositories for user ajfisher
# Fetched 68 repositories for user glennawatson
# Fetched 76 repositories for user ldiebold
# Fetched 4 repositories for user abraunegg
# Fetched 37 repositories for user cjbj
# Fetched 65 repositories for user xxfast
# Fetched 63 repositories for user ianw
# Fetched 99 repositories for user shsingh
# Fetched 266 repositories for user ocavue
# Fetched 210 repositories for user GenevieveBuckley
# Fetched 64 repositories for user Djelibeybi
# Fetched 73 repositories for user sync
# Fetched 70 repositories for user geeknam
# Fetched 29 repositories for user eigenbom
# Fetched 32 repositories for user honglytech
# Fetched 41 repositories for user chengzhag
# Fetched 69 repositories for user Falconerd
# Fetched 23 repositories for user adriangranados
# Fetched 81 repositories for user ronrest
# Fetched 44 repositories for user feilipu
# Fetched 27 repositories for user NiREvil
# Fetched 91 repositories for user d11wtq
# Fetched 15 repositories for user JohnyXu
# Fetched 45 repositories for user leonyuhanov
# Fetched 112 repositories for user robn
# Fetched 28 repositories for user wangdicoder
# Fetched 66 repositories for user taybenlor
# Fetched 78 repositories for user x-team
# Fetched 99 repositories for user simontime
# Fetched 98 repositories for user rajyraman
# Fetched 82 repositories for user davidobrien1985
# Fetched 54 repositories for user josephsurin
# Fetched 32 repositories for user tgdwyer
# Fetched 17 repositories for user nataliethenerd
# Fetched 6 repositories for user wilba
# Fetched 32 repositories for user gavinballard
# Fetched 46 repositories for user bungnoid
# Fetched 41 repositories for user skoval
# Fetched 24 repositories for user prodigysml
# Fetched 71 repositories for user JacksonBates
# Fetched 141 repositories for user plasticine
# Fetched 222 repositories for user timbertson
# Fetched 13 repositories for user NullTerminatorr
# Fetched 42 repositories for user julia-
# Fetched 8 repositories for user ibracorp
# Fetched 89 repositories for user mariovisic
# Fetched 44 repositories for user JaseZiv
# Fetched 63 repositories for user mdneuzerling
# Fetched 11 repositories for user minghao-wu
# Fetched 11 repositories for user DavidArayan
# Fetched 100 repositories for user loklaan
# Fetched 73 repositories for user DanielThomas
# Fetched 46 repositories for user learntodroid
# Fetched 19 repositories for user eliotharper
# Fetched 36 repositories for user philipbelesky
# Fetched 64 repositories for user emilytrau
# Fetched 87 repositories for user josh-
# Fetched 15 repositories for user KieraDOG
# Fetched 32 repositories for user mutoo
# Fetched 28 repositories for user harsilspatel
# Fetched 171 repositories for user mitchdenny
# Fetched 46 repositories for user martinbjeldbak
# Fetched 22 repositories for user jmattsson
# Fetched 30 repositories for user lvjian700
# Fetched 273 repositories for user plutext
# Fetched 22 repositories for user Aisuko
# Fetched 61 repositories for user geekscape
# Fetched 17 repositories for user dusterio
# Fetched 29 repositories for user vertxxyz
# Fetched 39 repositories for user EllyLoel
# Fetched 10 repositories for user akmand
# Fetched 25 repositories for user engram-design
# Fetched 228 repositories for user okeeffed
# Fetched 170 repositories for user tqwewe
# Fetched 80 repositories for user robskillington
# Fetched 110 repositories for user gonzalo-bulnes
# Fetched 56 repositories for user heycam
# Fetched 30 repositories for user colby-swandale
# Fetched 61 repositories for user tyconsulting
# Fetched 25 repositories for user rsharankumar
# Fetched 84 repositories for user bulkan
# Fetched 45 repositories for user theminecoder
# Fetched 89 repositories for user buntine
# Fetched 16 repositories for user collibra
# Fetched 6 repositories for user JiashuWu
# Fetched 31 repositories for user NETTUTS
# Fetched 107 repositories for user dgoodlad
# Fetched 35 repositories for user matthaywardwebdesign
# Fetched 23 repositories for user danilodelucio
# Fetched 76 repositories for user KyeOnDiscord
# Fetched 15 repositories for user corsc
# Fetched 196 repositories for user andycasey
# Fetched 60 repositories for user sayboras
# Fetched 93 repositories for user beekhof
# Fetched 216 repositories for user kawarimidoll
# Fetched 109 repositories for user heykarimoff
# Fetched 54 repositories for user luvuong-le
# Fetched 61 repositories for user rotorgames
# Fetched 18 repositories for user ricobl
# Fetched 68 repositories for user esteinig
# Fetched 144 repositories for user adam-gruer
# Fetched 32 repositories for user paulstefanday
# Fetched 29 repositories for user bryceadams
# Fetched 14 repositories for user AaronLiftig
# Fetched 125 repositories for user vinisalazar
# Fetched 16 repositories for user chongjason914
# Fetched 103 repositories for user alecthegeek
# Fetched 19 repositories for user Team-Nando
# Fetched 21 repositories for user Adnan25z
# Fetched 32 repositories for user TrustAGI-Lab
# Fetched 101 repositories for user peterwilsoncc
# Fetched 16 repositories for user pauldhunt
# Fetched 8 repositories for user rossp
# Fetched 100 repositories for user seek-oss
# Fetched 0 repositories for user Sportsbet-Internal
# Fetched 27 repositories for user michaeltaranto
# Fetched 24 repositories for user pazaan
# Fetched 31 repositories for user Gnzlt
# Fetched 71 repositories for user jacobh
# Fetched 75 repositories for user eastrd
# Fetched 18 repositories for user RenWenshan
# Fetched 17 repositories for user Zemerik
# Fetched 60 repositories for user ned2
# Fetched 34 repositories for user PaulBone
# Fetched 46 repositories for user kouky
# Fetched 40 repositories for user franciskim
# Fetched 23 repositories for user ziplab
# Fetched 26 repositories for user junhaow1
# Fetched 171 repositories for user Gurenax
# Fetched 943 repositories for user roachhd
# Fetched 84 repositories for user vadmium
# Fetched 85 repositories for user quad
# Fetched 108 repositories for user Gizmotronn
# Fetched 16 repositories for user danmacnish
# Fetched 102 repositories for user mdub
# Fetched 5 repositories for user 3xocyte
# Fetched 115 repositories for user TheDen
# Fetched 121 repositories for user yinchuandong
# Saved 29492 repositories to repositories.csv
# Created GitHub repository MELB_USERS and uploaded files.

# %%
#Q1
import pandas as pd

# Load the data from the CSV file
url = 'https://raw.githubusercontent.com/AlexStark110/MELB_USERS/refs/heads/main/users.csv'
users_df = pd.read_csv(url)

# Sort the DataFrame by the number of followers in descending order
sorted_users_df = users_df.sort_values(by='followers', ascending=False)

# Extract the top 5 users
top_5_users = sorted_users_df.head(5)

# List their logins in a comma-separated format
top_5_logins = ','.join(top_5_users['login'].tolist())

print(f"Top 5 users in Melbourne with the highest number of followers: {top_5_logins}")
# Out:
# Top 5 users in Melbourne with the highest number of followers: mosh-hamedani,TheCherno,haileys,rstacruz,jesseduffield

# %%
#q2
import pandas as pd

# Load the data from the CSV file
url = 'https://raw.githubusercontent.com/AlexStark110/MELB_USERS/refs/heads/main/users.csv'
users_df = pd.read_csv(url)

# Convert the 'created_at' column to datetime format
users_df['created_at'] = pd.to_datetime(users_df['created_at'])

# Sort the DataFrame by the 'created_at' column in ascending order
sorted_users_df = users_df.sort_values(by='created_at', ascending=True)

# Extract the 5 earliest registered users
earliest_5_users = sorted_users_df.head(5)

# List their logins in a comma-separated format
earliest_5_logins = ','.join(earliest_5_users['login'].tolist())

print(f"5 earliest registered GitHub users in Melbourne: {earliest_5_logins}")
# Out:
# 5 earliest registered GitHub users in Melbourne: toolmantim,crafterm,dgoodlad,Sutto,mdub

# %%
#q3
import pandas as pd

# Load the data from the CSV file
url = 'https://raw.githubusercontent.com/AlexStark110/MELB_USERS/refs/heads/main/repositories.csv'
repos_df = pd.read_csv(url)

# Check the first few rows of the DataFrame to understand its structure
print("First few rows of the DataFrame:")
print(repos_df.head())

# Check the columns of the DataFrame
print("\nColumns in the DataFrame:")
print(repos_df.columns)

# Check for missing values in the 'license_name' column
print("\nMissing values in 'license_name' column:")
print(repos_df['license_name'].isna().sum())

# Filter out missing licenses
repos_df = repos_df[repos_df['license_name'].notna()]

# Check the first few rows after filtering to ensure the filter worked
print("\nFirst few rows after filtering out missing licenses:")
print(repos_df.head())

# Count the occurrences of each license
license_counts = repos_df['license_name'].value_counts()

# Check the license counts to ensure they are calculated correctly
print("\nLicense counts:")
print(license_counts)

# Extract the top 3 most popular licenses
top_3_licenses = license_counts.head(3)

# List the license names in a comma-separated format
top_3_license_names = ','.join(top_3_licenses.index.tolist())

print(f"\n3 most popular licenses among these users: {top_3_license_names}")
# Out:
# First few rows of the DataFrame:
#            login                          full_name            created_at  \
# 0  mosh-hamedani    mosh-hamedani/angular-education  2017-08-10T05:30:30Z
# 1  mosh-hamedani      mosh-hamedani/angular2-course  2016-02-15T22:59:37Z
# 2  mosh-hamedani         mosh-hamedani/angularfire2  2016-09-06T00:06:45Z
# 3  mosh-hamedani  mosh-hamedani/AngularJS2-Learning  2017-08-10T05:41:03Z
# 4  mosh-hamedani      mosh-hamedani/awesome-angular  2017-08-10T05:45:49Z
#
#    stargazers_count  watchers_count    language  has_projects  has_wiki  \
# 0                22              22         NaN          True      True
# 1               130             130  TypeScript          True      True
# 2                15              15  TypeScript          True      True
# 3                28              28         NaN          True      True
# 4                35              35        HTML          True      True
#
#   license_name
# 0          NaN
# 1          NaN
# 2          mit
# 3          NaN
# 4      cc0-1.0
#
# Columns in the DataFrame:
# Index(['login', 'full_name', 'created_at', 'stargazers_count',
#        'watchers_count', 'language', 'has_projects', 'has_wiki',
#        'license_name'],
#       dtype='object')
#
# Missing values in 'license_name' column:
# 13627
#
# First few rows after filtering out missing licenses:
#             login                            full_name            created_at  \
# 2   mosh-hamedani           mosh-hamedani/angularfire2  2016-09-06T00:06:45Z
# 4   mosh-hamedani        mosh-hamedani/awesome-angular  2017-08-10T05:45:49Z
# 27      TheCherno  TheCherno/AnimatedSpriteCompression  2016-08-10T05:59:59Z
# 28      TheCherno                    TheCherno/Beneath  2014-04-30T11:05:50Z
# 29      TheCherno                      TheCherno/box2d  2020-07-03T06:19:58Z
#
#     stargazers_count  watchers_count    language  has_projects  has_wiki  \
# 2                 15              15  TypeScript          True      True
# 4                 35              35        HTML          True      True
# 27                19              19           C          True      True
# 28                 9               9        Java          True      True
# 29                29              29         C++          True     False
#
#    license_name
# 2           mit
# 4       cc0-1.0
# 27   apache-2.0
# 28      gpl-3.0
# 29          mit
#
# License counts:
# license_name
# mit                   8585
# other                 2513
# apache-2.0            1862
# gpl-3.0                740
# bsd-3-clause           646
# gpl-2.0                320
# bsd-2-clause           174
# isc                    165
# cc0-1.0                163
# mpl-2.0                115
# agpl-3.0               109
# unlicense              103
# cc-by-4.0               93
# lgpl-3.0                64
# lgpl-2.1                53
# cc-by-sa-4.0            30
# wtfpl                   27
# 0bsd                    18
# epl-1.0                 15
# bsd-3-clause-clear      13
# upl-1.0                 10
# ofl-1.1                  9
# mit-0                    8
# ms-pl                    7
# zlib                     6
# artistic-2.0             4
# afl-3.0                  4
# epl-2.0                  2
# bsl-1.0                  2
# bsd-4-clause             1
# postgresql               1
# lppl-1.3c                1
# vim                      1
# osl-3.0                  1
# Name: count, dtype: int64
#
# 3 most popular licenses among these users: mit,other,apache-2.0

# %%
#q4
import pandas as pd

# Load the data from the CSV file in the GitHub repository
url = 'https://raw.githubusercontent.com/AlexStark110/MELB_USERS/refs/heads/main/users.csv'
users_df = pd.read_csv(url)

# Clean the company names
def clean_company(company):
    if pd.isna(company):
        return ''
    return company.strip().lstrip('@').upper()

users_df['company'] = users_df['company'].apply(clean_company)

# Filter out empty company names
filtered_users_df = users_df[users_df['company'] != '']

# Count the occurrences of each company
company_counts = filtered_users_df['company'].value_counts()

# Find the company with the maximum count
if not company_counts.empty:
    most_common_company = company_counts.idxmax()
    most_common_company_count = company_counts.max()
    print(f"The majority of these developers work at: {most_common_company} with {most_common_company_count} developers")
else:
    print("No non-empty company names found.")
# Out:
# The majority of these developers work at: MONASH UNIVERSITY with 8 developers

# %%
#q5
import pandas as pd

# Load the data from the CSV file in the GitHub repository
url = 'https://raw.githubusercontent.com/AlexStark110/MELB_USERS/refs/heads/main/repositories.csv'
repos_df = pd.read_csv(url)

# Check the first few rows of the DataFrame to understand its structure
print("First few rows of the DataFrame:")
print(repos_df.head())

# Filter out missing languages
repos_df = repos_df[repos_df['language'].notna()]

# Count the occurrences of each language
language_counts = repos_df['language'].value_counts()

# Check the language counts to ensure they are calculated correctly
print("\nLanguage counts:")
print(language_counts)

# Find the most popular language
if not language_counts.empty:
    most_popular_language = language_counts.idxmax()
    most_popular_language_count = language_counts.max()
    print(f"\nThe most popular programming language among these users is: {most_popular_language} with {most_popular_language_count} repositories")
else:
    print("\nNo programming languages found.")
# Out:
# First few rows of the DataFrame:
#            login                          full_name            created_at  \
# 0  mosh-hamedani    mosh-hamedani/angular-education  2017-08-10T05:30:30Z
# 1  mosh-hamedani      mosh-hamedani/angular2-course  2016-02-15T22:59:37Z
# 2  mosh-hamedani         mosh-hamedani/angularfire2  2016-09-06T00:06:45Z
# 3  mosh-hamedani  mosh-hamedani/AngularJS2-Learning  2017-08-10T05:41:03Z
# 4  mosh-hamedani      mosh-hamedani/awesome-angular  2017-08-10T05:45:49Z
#
#    stargazers_count  watchers_count    language  has_projects  has_wiki  \
# 0                22              22         NaN          True      True
# 1               130             130  TypeScript          True      True
# 2                15              15  TypeScript          True      True
# 3                28              28         NaN          True      True
# 4                35              35        HTML          True      True
#
#   license_name
# 0          NaN
# 1          NaN
# 2          mit
# 3          NaN
# 4      cc0-1.0
#
# Language counts:
# language
# JavaScript       5957
# Ruby             2195
# Python           2017
# TypeScript       1134
# Go               1039
#                  ...
# YASnippet           1
# Modula-3            1
# Max                 1
# SuperCollider       1
# ABAP                1
# Name: count, Length: 173, dtype: int64
#
# The most popular programming language among these users is: JavaScript with 5957 repositories

# %%
#q6
import pandas as pd

# Load the data from the CSV files in the GitHub repository
users_url = 'https://raw.githubusercontent.com/AlexStark110/MELB_USERS/refs/heads/main/users.csv'
repos_url = 'https://raw.githubusercontent.com/AlexStark110/MELB_USERS/refs/heads/main/repositories.csv'
users_df = pd.read_csv(users_url)
repos_df = pd.read_csv(repos_url)

# Convert the 'created_at' column to datetime format
users_df['created_at'] = pd.to_datetime(users_df['created_at'])

# Filter users who joined after 2020
users_after_2020 = users_df[users_df['created_at'] > '2020-12-31']

# Get the logins of these users
logins_after_2020 = users_after_2020['login'].tolist()

# Filter repositories by these users
repos_after_2020 = repos_df[repos_df['login'].isin(logins_after_2020)]

# Filter out missing languages
repos_after_2020 = repos_after_2020[repos_after_2020['language'].notna()]

# Count the occurrences of each language
language_counts = repos_after_2020['language'].value_counts()

# Check the language counts to ensure they are calculated correctly
print("\nLanguage counts:")
print(language_counts)

# Find the second most popular language
if len(language_counts) > 1:
    second_most_popular_language = language_counts.index[1]
    second_most_popular_language_count = language_counts.iloc[1]
    print(f"\nThe second most popular programming language among users who joined after 2020 is: {second_most_popular_language} with {second_most_popular_language_count} repositories")
else:
    print("\nNot enough data to determine the second most popular programming language.")
# Out:
# Language counts:
# language
# Python              35
# JavaScript          18
# HTML                 6
# Astro                5
# C++                  4
# C#                   4
# TypeScript           4
# Java                 3
# CSS                  2
# Rust                 2
# Vue                  2
# MATLAB               1
# SCSS                 1
# Matlab               1
# PHP                  1
# Ruby                 1
# Kotlin               1
# Makefile             1
# Go                   1
# Shell                1
# ShaderLab            1
# Jupyter Notebook     1
# Name: count, dtype: int64
#
# The second most popular programming language among users who joined after 2020 is: JavaScript with 18 repositories

# %%
#q7
import pandas as pd

# Load the data from the CSV file in the GitHub repository
url = 'https://raw.githubusercontent.com/AlexStark110/MELB_USERS/refs/heads/main/repositories.csv'
repos_df = pd.read_csv(url)

# Filter out missing languages
repos_df = repos_df[repos_df['language'].notna()]

# Group by language and calculate the average number of stars
average_stars_per_language = repos_df.groupby('language')['stargazers_count'].mean()

# Find the language with the highest average number of stars
if not average_stars_per_language.empty:
    highest_avg_stars_language = average_stars_per_language.idxmax()
    highest_avg_stars_value = average_stars_per_language.max()
    print(f"The language with the highest average number of stars per repository is: {highest_avg_stars_language} with an average of {highest_avg_stars_value:.2f} stars")
else:
    print("No programming languages found.")
# Out:
# The language with the highest average number of stars per repository is: D with an average of 2521.50 stars

# %%
#q8
import pandas as pd

# Load the data from the CSV file in the GitHub repository
url = 'https://raw.githubusercontent.com/AlexStark110/MELB_USERS/refs/heads/main/users.csv'
users_df = pd.read_csv(url)

# Calculate leader_strength as followers / (1 + following)
users_df['leader_strength'] = users_df['followers'] / (1 + users_df['following'])

# Sort the DataFrame by leader_strength in descending order
sorted_users_df = users_df.sort_values(by='leader_strength', ascending=False)

# Extract the top 5 users
top_5_users = sorted_users_df.head(5)

# List their logins in a comma-separated format
top_5_logins = ','.join(top_5_users['login'].tolist())

print(f"Top 5 users in terms of leader_strength: {top_5_logins}")
# Out:
# Top 5 users in terms of leader_strength: mosh-hamedani,binarythistle,TheCherno,TuPayChain,rogerclarkmelbourne

# %%
#q9
import pandas as pd

# Load the data from the CSV file in the GitHub repository
url = 'https://raw.githubusercontent.com/AlexStark110/MELB_USERS/refs/heads/main/users.csv'
users_df = pd.read_csv(url)

# Check for missing values in the 'followers' and 'public_repos' columns
print("Missing values in 'followers' column:", users_df['followers'].isna().sum())
print("Missing values in 'public_repos' column:", users_df['public_repos'].isna().sum())

# Drop rows with missing values in 'followers' or 'public_repos' columns
users_df = users_df.dropna(subset=['followers', 'public_repos'])

# Check the first few rows of the DataFrame to understand its structure
print("\nFirst few rows of the DataFrame after dropping missing values:")
print(users_df[['followers', 'public_repos']].head())

# Calculate the correlation between the number of followers and the number of public repositories
correlation = users_df['followers'].corr(users_df['public_repos'])

# Print the correlation value rounded to three decimal places
print(f"\nCorrelation between followers and public repositories: {correlation:.3f}")
# Out:
# Missing values in 'followers' column: 0
# Missing values in 'public_repos' column: 0
#
# First few rows of the DataFrame after dropping missing values:
#    followers  public_repos
# 0      12786            27
# 1      11234            35
# 2       9391           372
# 3       6435           562
# 4       4578            60
#
# Correlation between followers and public repositories: 0.187

# %%
#q10
import pandas as pd
from sklearn.linear_model import LinearRegression

# Load the data from the CSV file in the GitHub repository
url = 'https://raw.githubusercontent.com/AlexStark110/MELB_USERS/refs/heads/main/users.csv'
users_df = pd.read_csv(url)

# Check for missing values in the 'followers' and 'public_repos' columns
print("Missing values in 'followers' column:", users_df['followers'].isna().sum())
print("Missing values in 'public_repos' column:", users_df['public_repos'].isna().sum())

# Drop rows with missing values in 'followers' or 'public_repos' columns
users_df = users_df.dropna(subset=['followers', 'public_repos'])

# Prepare the data for regression
X = users_df[['public_repos']].values
y = users_df['followers'].values

# Perform linear regression
model = LinearRegression()
model.fit(X, y)

# Extract the regression slope
slope = model.coef_[0]

# Print the regression slope rounded to three decimal places
print(f"Regression slope of followers on repos: {slope:.3f}")
# Out:
# Missing values in 'followers' column: 0
# Missing values in 'public_repos' column: 0
# Regression slope of followers on repos: 2.239

# %%
#q11
import pandas as pd

# Load the data from the CSV file in the GitHub repository
url = 'https://raw.githubusercontent.com/AlexStark110/MELB_USERS/refs/heads/main/repositories.csv'
repos_df = pd.read_csv(url)

# Ensure the 'has_projects' and 'has_wiki' columns are in boolean format
repos_df['has_projects'] = repos_df['has_projects'].astype(bool)
repos_df['has_wiki'] = repos_df['has_wiki'].astype(bool)

# Calculate the correlation between 'has_projects' and 'has_wiki'
correlation = repos_df['has_projects'].corr(repos_df['has_wiki'])

# Print the correlation value rounded to three decimal places
print(f"Correlation between having projects enabled and having wiki enabled: {correlation:.3f}")
# Out:
# Correlation between having projects enabled and having wiki enabled: 0.378

# %%
#q12
import pandas as pd

# Load the users data from the CSV file
users_df = pd.read_csv('https://raw.githubusercontent.com/AlexStark110/MELB_USERS/refs/heads/main/users.csv')

# Filter hireable and non-hireable users
hireable_users = users_df[users_df['hireable'] == True]
non_hireable_users = users_df[users_df['hireable'].isna() | (users_df['hireable'] == False)]

# Calculate average following for both groups
average_hireable_following = hireable_users['following'].mean()
average_non_hireable_following = non_hireable_users['following'].mean()

# Calculate the difference
difference = average_hireable_following - average_non_hireable_following

# Print the result rounded to three decimal places
print(f'Difference in average following (hireable - non-hireable): {difference:.3f}')
# Out:
# Difference in average following: nan

# %%
#q13
import pandas as pd

# Load the data from the CSV file in the GitHub repository
url = 'https://raw.githubusercontent.com/AlexStark110/MELB_USERS/refs/heads/main/users.csv'
users_df = pd.read_csv(url)

# Filter out users without bios
users_with_bios = users_df[users_df['bio'].notna() & (users_df['bio'] != '')]

# Calculate the length of each bio in Unicode words (split by whitespace)
users_with_bios['bio_length'] = users_with_bios['bio'].apply(lambda x: len(x.split()))

# Calculate the correlation between the length of the bio and the number of followers
correlation = users_with_bios['bio_length'].corr(users_with_bios['followers'])

# Print the correlation value rounded to three decimal places
print(f"Correlation between bio length and followers: {correlation:.3f}")
# Out:
# Correlation between bio length and followers: 0.048
# <ipython-input-6-ec9c527f035a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users_with_bios['bio_length'] = users_with_bios['bio'].apply(lambda x: len(x.split()))

# %%
#q14
import pandas as pd

# Load the data from the CSV file in the GitHub repository
url = 'https://raw.githubusercontent.com/AlexStark110/MELB_USERS/refs/heads/main/repositories.csv'
repos_df = pd.read_csv(url)

# Convert the 'created_at' column to datetime format
repos_df['created_at'] = pd.to_datetime(repos_df['created_at'])

# Filter repositories created on weekends (Saturday and Sunday)
repos_df['weekday'] = repos_df['created_at'].dt.weekday
weekend_repos = repos_df[repos_df['weekday'] >= 5]

# Count the number of repositories created by each user on weekends
weekend_repo_counts = weekend_repos['login'].value_counts()

# Extract the top 5 users
top_5_users = weekend_repo_counts.head(5)

# List their logins in a comma-separated format
top_5_logins = ','.join(top_5_users.index.tolist())

print(f"Top 5 users who created the most repositories on weekends: {top_5_logins}")
# Out:
# Top 5 users who created the most repositories on weekends: roachhd,wolfeidau,karkranikhil,rstacruz,plutext

# %%
#q15
import pandas as pd

# Load the users data from the CSV file
users_df = pd.read_csv('https://raw.githubusercontent.com/AlexStark110/MELB_USERS/refs/heads/main/users.csv')

# Total number of users
total_users = len(users_df)

# Filter hireable and non-hireable users
hireable_users = users_df[users_df['hireable'] == True]
non_hireable_users = users_df[users_df['hireable'].isna() | (users_df['hireable'] == False)]

# Calculate the fraction of users with email in both groups
fraction_hireable_with_email = hireable_users['email'].notna().mean()
fraction_non_hireable_with_email = non_hireable_users['email'].notna().mean()

# Calculate the difference
difference = fraction_hireable_with_email - fraction_non_hireable_with_email

# Print the result rounded to three decimal places
print(f'Difference in fraction of users with email: {difference:.3f}')
# Out:
# Difference in fraction of users with email: nan

# %%
#q16
import pandas as pd

# Load the data from the CSV file in the GitHub repository
url = 'https://raw.githubusercontent.com/AlexStark110/MELB_USERS/refs/heads/main/users.csv'
users_df = pd.read_csv(url)

# Filter out users without names
users_with_names = users_df[users_df['name'].notna() & (users_df['name'] != '')]

# Extract the last word from each name as the surname
users_with_names['surname'] = users_with_names['name'].apply(lambda x: x.strip().split()[-1])

# Count the occurrences of each surname
surname_counts = users_with_names['surname'].value_counts()

# Find the maximum count
max_count = surname_counts.max()

# Find the most common surname(s)
most_common_surnames = surname_counts[surname_counts == max_count].index.tolist()

# Sort the most common surnames alphabetically
most_common_surnames.sort()

# Print the most common surname(s) in a comma-separated format
print(f"Most common surname(s): {', '.join(most_common_surnames)}")
# Out:
# Most common surname(s): Jackson, Wang
# <ipython-input-25-08ed8acc59f1>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users_with_names['surname'] = users_with_names['name'].apply(lambda x: x.strip().split()[-1])
